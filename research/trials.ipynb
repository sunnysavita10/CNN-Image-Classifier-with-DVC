# %%
import os
from ensure import ensure_annotations

# %%
@ensure_annotations
def add_number(a:int,b:int)->int:
    return a * b

# %%
add_number(10,"sonu")
# Out:
# ---------------------------------------------------------------------------
# EnsureError                               Traceback (most recent call last)
# c:\Complete_Content\All_Project\fdsdcnnclassifier\research\trials.ipynb Cell 3 line 1
# ----> <a href='vscode-notebook-cell:/c%3A/Complete_Content/All_Project/fdsdcnnclassifier/research/trials.ipynb#W4sZmlsZQ%3D%3D?line=0'>1</a> add_number(10,"sonu")
#
# File c:\Complete_Content\All_Project\fdsdcnnclassifier\env\lib\site-packages\ensure\main.py:845, in WrappedFunctionReturn.__call__(self, *args, **kwargs)
#     840     if not isinstance(value, templ):
#     841         msg = (
#     842             "Argument {arg} of type {valt} to {f} "
#     843             "does not match annotation type {t}"
#     844         )
# --> 845         raise EnsureError(msg.format(
#     846             arg=arg, f=self.f, t=templ, valt=type(value)
#     847         ))
#     849 return_val = self.f(*args, **kwargs)
#     850 if not isinstance(return_val, self.return_templ):
#
# EnsureError: Argument b of type <class 'str'> to <function add_number at 0x000001FA8EF92A60> does not match annotation type <class 'int'>

# %%
add_number(10,200)
# Out:
# 2000

# %%
  datagenerator_kwargs = dict(
            rescale = 1./255,
            validation_split=0.20
        )

# %%
  datagenerator_kwargs
# Out:
# {'rescale': 0.00392156862745098, 'validation_split': 0.2}

# %%
 dataflow_kwargs = dict(
            target_size=config.params_image_size[:-1],
            batch_size=config.params_batch_size,
            interpolation="bilinear"
        )
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# c:\Complete_Content\All_Project\fdsdcnnclassifier\research\trials.ipynb Cell 7 line 2
#       <a href='vscode-notebook-cell:/c%3A/Complete_Content/All_Project/fdsdcnnclassifier/research/trials.ipynb#W6sZmlsZQ%3D%3D?line=0'>1</a> dataflow_kwargs = dict(
# ----> <a href='vscode-notebook-cell:/c%3A/Complete_Content/All_Project/fdsdcnnclassifier/research/trials.ipynb#W6sZmlsZQ%3D%3D?line=1'>2</a>            target_size=self.config.params_image_size[:-1],
#       <a href='vscode-notebook-cell:/c%3A/Complete_Content/All_Project/fdsdcnnclassifier/research/trials.ipynb#W6sZmlsZQ%3D%3D?line=2'>3</a>            batch_size=self.config.params_batch_size,
#       <a href='vscode-notebook-cell:/c%3A/Complete_Content/All_Project/fdsdcnnclassifier/research/trials.ipynb#W6sZmlsZQ%3D%3D?line=3'>4</a>            interpolation="bilinear"
#       <a href='vscode-notebook-cell:/c%3A/Complete_Content/All_Project/fdsdcnnclassifier/research/trials.ipynb#W6sZmlsZQ%3D%3D?line=4'>5</a>        )
#
# NameError: name 'self' is not defined
